# %% [markdown]
# <a href="https://colab.research.google.com/github/jnishikuni/07MBIG---Visualizacion-de-Datos/blob/master/Visualizaci%C3%B3n_AG3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Autor: Jorge Nishikuni
#
# Master en Big Data y Data Science
#
# Asignatura Visualizacion de Datos
#
# Link Github: https://github.com/jnishikuni/07MBIG---Visualizacion-de-Datos

# %%
import pandas as pd
import numpy as np
import requests
import seaborn as sns
import matplotlib.pyplot as plt
import io

# %%
url="https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"
s=requests.get(url).content
titanic=pd.read_csv(io.StringIO(s.decode('utf-8')))

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
# survived       891 non-null int64
# pclass         891 non-null int64
# sex            891 non-null object
# age            714 non-null float64
# sibsp          891 non-null int64
# parch          891 non-null int64
# fare           891 non-null float64
# embarked       889 non-null object
# class          891 non-null object
# who            891 non-null object
# adult_male     891 non-null bool
# deck           203 non-null object
# embark_town    889 non-null object
# alive          891 non-null object
# alone          891 non-null bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.3+ KB

# %%
titanic.rename(columns={'pclass': 'clase'}, inplace=True)

# %%
titanic.rename(columns={'fare': 'tarifa'}, inplace=True)

# %%
titanic.clase.unique()
# Out:
# array([3, 1, 2])

# %%
titanic.head(5)
# Out:
#    survived  clase     sex   age  sibsp  parch   tarifa embarked  class  \
# 0         0      3    male  22.0      1      0   7.2500        S  Third
# 1         1      1  female  38.0      1      0  71.2833        C  First
# 2         1      3  female  26.0      0      0   7.9250        S  Third
# 3         1      1  female  35.0      1      0  53.1000        S  First
# 4         0      3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#Consulta con condiciones
titanic[
 (titanic.sex == 'female')
 & (titanic['clase'].isin(['1','2']))
 & (titanic.age > 35 )
 & (titanic.survived == 0)
]
# Out:
#      survived  clase     sex   age  sibsp  parch   tarifa embarked   class  \
# 177         0      1  female  50.0      0      0  28.7125        C   First
# 357         0      2  female  38.0      0      0  13.0000        S  Second
# 772         0      2  female  57.0      0      0  10.5000        S  Second
# 854         0      2  female  44.0      1      0  26.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 177  woman       False    C    Cherbourg    no   True
# 357  woman       False  NaN  Southampton    no   True
# 772  woman       False    E  Southampton    no   True
# 854  woman       False  NaN  Southampton    no  False

# %%
sns.distplot (titanic.age.dropna( ))
sns.plt.show ( )
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
sns.set(font_scale=0.5)
g = sns.FacetGrid(titanic, row='survived',col='clase')
g.map(sns.distplot, "age")
sns.plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
#Diagrama de dispersion con Distribucion de cada variable: tarifa(precio)/age(edad)
sns.jointplot(data=titanic, x='age', y='tarifa',
kind='reg', color='b')
sns.plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
#Define un subconjuto de datos con las variables numéricas
titanic_num = titanic[['survived','clase','sibsp','parch','tarifa']]
#Hace una matriz de diagramas de dispersión de parejas de variables.
sns.pairplot(titanic_num, hue="survived")
sns.plt.show()

# %%
sns.set(style="ticks")
df = sns.load_dataset("iris")
sns.pairplot(df, hue="species")

# %%
# A continuacion se visualiza la distribucion de clase/edad y los supervivientes del titanic
# Se usa la clase FacetGrid la cual ayuda visualizando la distribucion de una variable tambien con las relaciones entre multiples variables usando paneles, se usan 3 
# dimensiones: row (para la variable sex), col (para la variable clase) y hue (para la variable survived), las 2 primeras variables tienen correspondencia con los ejes
 
g = sns.FacetGrid(titanic, col="clase", row="sex", hue="survived",margin_titles=True)
g.map(plt.hist, "age")
g.add_legend();

# %%
# Se observa claramente que los supervivientes del titanic estaban muy directamente relacionados a mayor clase (1) y con su genero (female) y con una edad promedio de 23-27 años
